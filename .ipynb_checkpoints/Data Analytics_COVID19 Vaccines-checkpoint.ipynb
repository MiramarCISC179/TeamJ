# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('covid19_vaccinations_in_the_united_states.csv')
df.head()
# Out:
#   State/Territory/Federal Entity  Total Doses Delivered  \
# 0                         Alaska                 792055
# 1                        Alabama                4348790
# 2                       Arkansas                2714140
# 3                 American Samoa                  54030
# 4                        Arizona                7417255
#
#    Doses Delivered per 100K  18+ Doses Delivered per 100K  \
# 0                  108272.0                      143602.0
# 1                   88693.0                      113995.0
# 2                   89938.0                      117107.0
# 3                   97021.0                      124387.0
# 4                  101903.0                      131547.0
#
#    Total Doses Administered by State where Administered  \
# 0                                             580781
# 1                                            2859591
# 2                                            1938998
# 3                                              40091
# ...

# %%
# Read headers
df.columns

# Read each column
print (df['State/Territory/Federal Entity'])

# Read each row
# print(df.iloc[0:4])
# for index, row in df.iterrows();
#   print(index,row['State/Territory/Federal Entity'])
df.loc[df['State/Territory/Federal Entity'] == "California"]


# Read from a specific location
#print(df.iloc[2])
# Out:
# 0             Alaska
# 1            Alabama
# 2           Arkansas
# 3     American Samoa
# 4            Arizona
#            ...
# 58           Vermont
# 59        Washington
# 60         Wisconsin
# 61     West Virginia
# 62           Wyoming
# Name: State/Territory/Federal Entity, Length: 63, dtype: object
#   State/Territory/Federal Entity  Total Doses Delivered  \
# 0                         Alaska                 792055
# 1                        Alabama                4348790
# 2                       Arkansas                2714140
# 3                 American Samoa                  54030
#
#    Doses Delivered per 100K  18+ Doses Delivered per 100K  \
# 0                  108272.0                      143602.0
# 1                   88693.0                      113995.0
# 2                   89938.0                      117107.0
# 3                   97021.0                      124387.0
#
#    Total Doses Administered by State where Administered  \
# ...
